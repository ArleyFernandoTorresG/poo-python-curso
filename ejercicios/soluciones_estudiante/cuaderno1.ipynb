# %%
import pandas as pd

# %%
def primo(n):
    for i in range(2,n):
        if n%i == 0:
            return False
    return True

# %%
primo(15), primo(27), primo(13)
# Out:
# (False, False, True)
